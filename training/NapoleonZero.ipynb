# %% [markdown]
# <a href="https://colab.research.google.com/github/crybot/NapoleonZero/blob/master/NapoleonZero.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
  # !pip install tensorflow-gpu==2.1.0
except Exception:
  pass
import tensorflow as tf

from tensorflow import keras
import numpy as np
import pandas as pd
import io

gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Mon Oct 12 13:25:40 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.23.05    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    38W / 300W |  15619MiB / 16130MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Install and log into Weights & Biases

# %% [markdown]
# # Dataset management

# %% [markdown]
# ### Download dataset from GitHub

# %%
import subprocess
import os

cmd = ['git', 'clone', 'https://github.com/crybot/NapoleonZero.git']
subprocess.run(cmd)

DRIVE_PATH = './NapoleonZero'
# Read dataset file
with open('{path}/converted-depth1.csv'.format(path=DRIVE_PATH), 'r') as f:
  # use dtype=str when parsing the csv to avoid converting bitboards 
  # in integer values (e.g ....001 -> 1)
  df = pd.read_csv(f, header=None, dtype=str)
  dataset = np.array(df.values)

def string_to_matrix(bitboard):
  return(np.array(list(bitboard), dtype=np.float32).reshape(8,8))

print('Initial dataset shape')
print(dataset.shape)

np.random.seed(42) # Reset numpy's random seed
np.random.shuffle(dataset)
#dataset = dataset[:10000, :]

# Scores (target) preprocessing
scores = dataset[:, 16:].astype(np.float32) # score in centipawns
scores /= 100 # score is in centipawns, so we divide by 100 (i.e. pawn = 1)
dataset = dataset[np.abs(scores[:, 0]) < 10] # remove positions with too high scores
scores = dataset[:, 16:].astype(np.float32) # also remove the scores (see above)

colors = dataset[:, 12:13].astype(np.float32) # side to move: 0 white, 1 black
epsquares = dataset[:, 13:14].astype(np.float32) # enpassant square: 0-63, 65 if there is none
castlings = dataset[:, 14:15].astype(np.float32) # castling status: integer value
depths = dataset[:, 15:16].astype(np.float32) # depth of the search: 1-100
scores[colors == 1] *= -1.0 # change black's score perspective: always evaluate white's position


# The first 12 fields of the dataset are bitboards
bitboards = dataset[:, 0:12] 
# The bitboards dataset has shape Nx12X1 where 1 is a string of 64 characters.
# We want Nx12x8x8 floats
bitboards = np.array([[string_to_matrix(b) for b in bs] for bs in bitboards])

print(bitboards.shape)
print(scores.shape)
print(scores[1])
# reshaped = np.concatenate((bitboards, scores), axis=1)
# print(reshaped.shape)
# print(reshaped[0])
# Out:
# Initial dataset shape
# (100000, 17)
# (99793, 12, 8, 8)
# (99793, 1)
# [25.]

# %% [markdown]
# ### Dataset splitting

# %%
# ONLY USED TO LOG THE CONFIGURATION OF THE TRAINING STAGE INTO W&B
TRAIN_SPLIT = 0.7
VAL_SPLIT = 0.15
TEST_SPLIT = 0.15

# Split a given dataset into training, validation and test sets
def split_dataset(ds, train=0.7, val=0.15):
  train_ds = ds[0:int(len(dataset)*train)]
  val_ds = ds[int(len(dataset)*train):int(len(dataset)*(train + val))]
  test_ds = ds[int(len(dataset)*(train + val)):]
  return (train_ds, val_ds, test_ds)

(train_ds, val_ds, test_ds) = split_dataset(bitboards, TRAIN_SPLIT, VAL_SPLIT)
(train_color, val_color, test_color) = split_dataset(colors, TRAIN_SPLIT, VAL_SPLIT)
(train_y, val_y, test_y) = split_dataset(scores, TRAIN_SPLIT, VAL_SPLIT)

print(train_ds.shape)
print(val_ds.shape)
print(test_ds.shape)

print(train_y.shape)
print(val_y.shape)
print(test_y.shape)
# Out:
# (69855, 12, 8, 8)
# (14969, 12, 8, 8)
# (14969, 12, 8, 8)
# (69855, 1)
# (14969, 1)
# (14969, 1)

# %% [markdown]
# # Model creation

# %% [markdown]
# ## Configuration and Hyperparameters

# %%
# initial hyperparameters values
default_config = {
    # FIXED
    "train_split": TRAIN_SPLIT,
    "val_split": VAL_SPLIT,
    "test_split": TEST_SPLIT,
    "monitor": 'val_loss',
    "patience": 200,
    "batch_normalization": True,
    "seed": 42,

    # VARIABLE
    "epochs": 1000,
    "batch_size": 12000,
    "learning_rate": 1e-3,
    "weight_decay": 5e-5,
    "dropout_rate": 0.5,
    "cnn_kernels": 64,
    "cnn_window": (2,2),
    "cnn_layers": 3,
    "optimizer": 'adam',
    "activation": 'relu',
    "loss": 'mse'
}

val_tf_ds = tf.data.Dataset.from_tensor_slices(
    ({"bitboards_in": val_ds, "color_in": val_color},
    {'output': val_y})
    )
val_tf_ds = val_tf_ds.cache()
val_tf_ds = val_tf_ds.batch(len(val_ds)) # single batch
val_tf_ds = val_tf_ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

print(val_tf_ds)
print(tf.__version__)

# print(list(val_tf_ds.as_numpy_iterator())[0][1]['output'])
# Out:
# <PrefetchDataset shapes: ({bitboards_in: (None, 12, 8, 8), color_in: (None, 1)}, {output: (None, 1)}), types: ({bitboards_in: tf.float32, color_in: tf.float32}, {output: tf.float32})>
# 2.3.0

# %% [markdown]
# ## Convolutional/Connected model with skip connections

# %%
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D, Dropout, GaussianDropout, SeparableConv1D
from tensorflow.keras.layers import BatchNormalization, MaxPool2D
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Input, Dense, Activation
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import RMSprop, SGD, Adam, Nadam
from tensorflow.keras.losses import Huber

import tensorflow_datasets as tfds
import datetime
  
config = default_config

# TODO: try different orders of conv,bn,relu
def conv_block(input, filters=16, kernel_size=(2,2), activation='relu',
               input_shape=None,
               normalize=True,
               pool=False,
               decay=1e-4,
               data_format='channels_first'):
  if input_shape is not None:
    conv = layers.Conv2D(filters, kernel_size,
                        data_format=data_format,
                        padding='same',
                        kernel_regularizer=l2(decay),
                        input_shape=input_shape)(input)
  else:
    conv = layers.Conv2D(filters, kernel_size,
                        data_format=data_format,
                        padding='same',
                        kernel_regularizer=l2(decay))(input)

                       
  if activation is not None:
    conv = Activation(activation)(conv)
  if normalize:
    conv = layers.BatchNormalization()(conv)
  if pool:
    conv = MaxPool2D(pool_size=(2,2), data_format=data_format)(conv)

  return conv


def build_model(config):
  # Define inputs to the network
  main_input = Input(shape=(12, 8, 8), name='bitboards_in')
  color_input = Input(shape=(1,), name='color_in')

  # Boolean indicating whether we should use batch normalization or not
  normalize = config['batch_normalization'] 
  # Number of kernels (filters) for each layer of the CNN
  kernels = config['cnn_kernels']
  # Window size of each kernel
  window = config['cnn_window']
  decay = config['weight_decay']
  activation = config['activation']
  CNN_layers = config['cnn_layers']
  
  ################################################################################
  ########################## CONVOLUTIONAL LAYERS ################################
  # Stack of convolutional and pooling layers: each conv layer produces N filters
  # from its inputs with a window size of W. The output of the convolution 
  # is zero-padded to maintain the same dimensionality
  
  # First block
  conv = conv_block(main_input, kernels, window,
                    decay=decay,
                    activation=activation,
                    input_shape=(12,8,8))

  # Second block
  conv = conv_block(conv, kernels, window, activation, decay=decay, pool=True)
  # Third block
  kernels *= 2
  conv = conv_block(conv, kernels, window, activation, decay=decay, pool=True)
  # Fourth block
  kernels *= 2
  conv = conv_block(conv, kernels, window, activation, decay=decay, pool=False)

  # Series of non pooling convolutional blocks
  for i in range(CNN_layers):
    conv = conv_block(conv, kernels, window, activation, decay=decay)

  # Last CNN block
  kernels *= 2
  conv = conv_block(conv, kernels, window, activation, decay=decay)
  # Global pooling layer
  # conv = layers.GlobalMaxPool2D(data_format='channels_first')(conv)
  
  ################################################################################
  ################################################################################
  
  flattened = layers.Flatten()(conv)
  flattened = layers.Dropout(config['dropout_rate'])(flattened) # Apply dropout to approximate model set averaging
  flattened = layers.concatenate([flattened, color_input])

  
  ################################################################################
  ############################## DENSE LAYERS ####################################
  layer2 = Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(decay))(flattened)
  layer2 = Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(decay))(layer2)
  # layer2 = Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(decay))(layer2)
  output = Dense(1, activation='linear', kernel_regularizer=tf.keras.regularizers.l2(decay),
                 name='output')(layer2)
  ################################################################################
  
  model = Model(inputs=[main_input, color_input],
                outputs=[output])

  return model

def get_optimizer(config):
  name = config['optimizer']
  if name =='sgd':
    return SGD(lr=config['learning_rate'], decay=config['weight_decay'], momentum=0.8, nesterov=False)
  elif name =='rmsprop':
    return RMSprop(lr=['config.learning_rate'], decay=1e-5)
  elif name =='adam':
    return Adam(lr=config['learning_rate'], beta_1=0.9, beta_2=0.999)
    # return Adam(lr=config.learning_rate, beta_1=0.9, beta_2=0.999, clipnorm=1.0)
  elif name =='nadam':
    return Nadam(lr=config['learning_rate'], beta_1=0.9, beta_2=0.999, clipnorm=1.0)
  return None

def train():
  tf_ds = tf.data.Dataset.from_tensor_slices(
      ({"bitboards_in": train_ds, "color_in": train_color},
      {'output': train_y}))
  # tf_ds = tf.data.Dataset.from_tensor_slices((train_ds, train_y))
  tf_ds = tf_ds.cache()
  tf_ds = tf_ds.batch(config['batch_size'], drop_remainder=False)
  tf_ds = tf_ds.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

  print(np.array(tf_ds.as_numpy_iterator()).shape)
  print(tf_ds)

  loss = config['loss']
  model = build_model(config)
  optimizer = get_optimizer(config)
  model.compile(optimizer=optimizer,
              loss=loss,
              metrics=[tf.metrics.RootMeanSquaredError()])
  model.summary()

  early_stopping = tf.keras.callbacks.EarlyStopping(
     monitor=config['monitor'],
     patience=config['patience'],
     min_delta=0.01,
     restore_best_weights=True,
     verbose=2)

  reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(
     monitor='val_loss',
     factor=0.7,
     mode='min',
     verbose=1,
     patience=40, min_lr=0.0001)

  model.fit(tf_ds,
            epochs=config['epochs'], 
            # batch_size=config['batch_size'],
            validation_data=val_tf_ds,
            # validation_data=(val_dataset, val_target),
            verbose=2,
            callbacks=[
                      # early_stopping,
                      reduce_lr
                       ])

# %% [markdown]
# # Training

# %%
train()
# Out:
# ()
# <PrefetchDataset shapes: ({bitboards_in: (None, 12, 8, 8), color_in: (None, 1)}, {output: (None, 1)}), types: ({bitboards_in: tf.float32, color_in: tf.float32}, {output: tf.float32})>
# Model: "functional_45"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# bitboards_in (InputLayer)       [(None, 12, 8, 8)]   0
# __________________________________________________________________________________________________
# conv2d_176 (Conv2D)             (None, 64, 8, 8)     3136        bitboards_in[0][0]
# __________________________________________________________________________________________________
# activation_176 (Activation)     (None, 64, 8, 8)     0           conv2d_176[0][0]
# __________________________________________________________________________________________________
# batch_normalization_176 (BatchN (None, 64, 8, 8)     32          activation_176[0][0]
# __________________________________________________________________________________________________
# conv2d_177 (Conv2D)             (None, 64, 8, 8)     16448       batch_normalization_176[0][0]
# __________________________________________________________________________________________________
# activation_177 (Activation)     (None, 64, 8, 8)     0           conv2d_177[0][0]
# __________________________________________________________________________________________________
# batch_normalization_177 (BatchN (None, 64, 8, 8)     32          activation_177[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_21 (MaxPooling2D) (None, 64, 4, 4)     0           batch_normalization_177[0][0]
# __________________________________________________________________________________________________
# conv2d_178 (Conv2D)             (None, 128, 4, 4)    32896       max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# activation_178 (Activation)     (None, 128, 4, 4)    0           conv2d_178[0][0]
# __________________________________________________________________________________________________
# batch_normalization_178 (BatchN (None, 128, 4, 4)    16          activation_178[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_22 (MaxPooling2D) (None, 128, 2, 2)    0           batch_normalization_178[0][0]
# __________________________________________________________________________________________________
# conv2d_179 (Conv2D)             (None, 256, 2, 2)    131328      max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# activation_179 (Activation)     (None, 256, 2, 2)    0           conv2d_179[0][0]
# __________________________________________________________________________________________________
# batch_normalization_179 (BatchN (None, 256, 2, 2)    8           activation_179[0][0]
# __________________________________________________________________________________________________
# conv2d_180 (Conv2D)             (None, 256, 2, 2)    262400      batch_normalization_179[0][0]
# __________________________________________________________________________________________________
# activation_180 (Activation)     (None, 256, 2, 2)    0           conv2d_180[0][0]
# __________________________________________________________________________________________________
# batch_normalization_180 (BatchN (None, 256, 2, 2)    8           activation_180[0][0]
# __________________________________________________________________________________________________
# conv2d_181 (Conv2D)             (None, 256, 2, 2)    262400      batch_normalization_180[0][0]
# __________________________________________________________________________________________________
# activation_181 (Activation)     (None, 256, 2, 2)    0           conv2d_181[0][0]
# __________________________________________________________________________________________________
# batch_normalization_181 (BatchN (None, 256, 2, 2)    8           activation_181[0][0]
# __________________________________________________________________________________________________
# conv2d_182 (Conv2D)             (None, 256, 2, 2)    262400      batch_normalization_181[0][0]
# __________________________________________________________________________________________________
# activation_182 (Activation)     (None, 256, 2, 2)    0           conv2d_182[0][0]
# __________________________________________________________________________________________________
# batch_normalization_182 (BatchN (None, 256, 2, 2)    8           activation_182[0][0]
# __________________________________________________________________________________________________
# conv2d_183 (Conv2D)             (None, 512, 2, 2)    524800      batch_normalization_182[0][0]
# __________________________________________________________________________________________________
# activation_183 (Activation)     (None, 512, 2, 2)    0           conv2d_183[0][0]
# __________________________________________________________________________________________________
# batch_normalization_183 (BatchN (None, 512, 2, 2)    8           activation_183[0][0]
# __________________________________________________________________________________________________
# flatten_22 (Flatten)            (None, 2048)         0           batch_normalization_183[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 2048)         0           flatten_22[0][0]
# __________________________________________________________________________________________________
# color_in (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 2049)         0           dropout_11[0][0]
#                                                                  color_in[0][0]
# __________________________________________________________________________________________________
# dense_66 (Dense)                (None, 128)          262400      concatenate_22[0][0]
# __________________________________________________________________________________________________
# dense_67 (Dense)                (None, 256)          33024       dense_66[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 1)            257         dense_67[0][0]
# ==================================================================================================
# Total params: 1,791,609
# Trainable params: 1,791,549
# Non-trainable params: 60
# __________________________________________________________________________________________________
# Epoch 1/1000
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0645s vs `on_train_batch_end` time: 0.1219s). Check your callbacks.
# 6/6 - 2s - loss: 9432.6104 - root_mean_squared_error: 97.1211 - val_loss: 10050.1816 - val_root_mean_squared_error: 100.2501
# Epoch 2/1000
# 6/6 - 1s - loss: 8928.2832 - root_mean_squared_error: 94.4891 - val_loss: 10012.4971 - val_root_mean_squared_error: 100.0620
# Epoch 3/1000
# 6/6 - 1s - loss: 8704.3643 - root_mean_squared_error: 93.2967 - val_loss: 9993.6406 - val_root_mean_squared_error: 99.9677
# Epoch 4/1000
# 6/6 - 1s - loss: 8579.1553 - root_mean_squared_error: 92.6232 - val_loss: 10051.9102 - val_root_mean_squared_error: 100.2587
# Epoch 5/1000
# 6/6 - 1s - loss: 8255.3662 - root_mean_squared_error: 90.8585 - val_loss: 10076.0098 - val_root_mean_squared_error: 100.3788
# Epoch 6/1000
# 6/6 - 1s - loss: 8010.9219 - root_mean_squared_error: 89.5032 - val_loss: 10095.8691 - val_root_mean_squared_error: 100.4777
# Epoch 7/1000
# 6/6 - 1s - loss: 7709.5049 - root_mean_squared_error: 87.8032 - val_loss: 10122.4580 - val_root_mean_squared_error: 100.6099
# Epoch 8/1000
# 6/6 - 1s - loss: 7316.2183 - root_mean_squared_error: 85.5343 - val_loss: 10205.1533 - val_root_mean_squared_error: 101.0201
# Epoch 9/1000
# 6/6 - 1s - loss: 6844.7017 - root_mean_squared_error: 82.7321 - val_loss: 10437.4033 - val_root_mean_squared_error: 102.1631
# Epoch 10/1000
# 6/6 - 1s - loss: 6328.7930 - root_mean_squared_error: 79.5531 - val_loss: 10994.4912 - val_root_mean_squared_error: 104.8542
# Epoch 11/1000
# 6/6 - 1s - loss: 5932.9736 - root_mean_squared_error: 77.0252 - val_loss: 11699.3340 - val_root_mean_squared_error: 108.1630
# Epoch 12/1000
# 6/6 - 1s - loss: 5529.8320 - root_mean_squared_error: 74.3622 - val_loss: 12286.7549 - val_root_mean_squared_error: 110.8452
# Epoch 13/1000
# 6/6 - 1s - loss: 5111.2788 - root_mean_squared_error: 71.4925 - val_loss: 13381.0166 - val_root_mean_squared_error: 115.6759
# Epoch 14/1000
# 6/6 - 1s - loss: 4736.1665 - root_mean_squared_error: 68.8191 - val_loss: 14948.3809 - val_root_mean_squared_error: 122.2632
# Epoch 15/1000
# 6/6 - 1s - loss: 4515.1289 - root_mean_squared_error: 67.1940 - val_loss: 16692.7500 - val_root_mean_squared_error: 129.2000
# Epoch 16/1000
# 6/6 - 1s - loss: 4242.8418 - root_mean_squared_error: 65.1363 - val_loss: 18158.5117 - val_root_mean_squared_error: 134.7531
# Epoch 17/1000
# 6/6 - 1s - loss: 3987.0173 - root_mean_squared_error: 63.1420 - val_loss: 20567.0723 - val_root_mean_squared_error: 143.4119
# Epoch 18/1000
# 6/6 - 1s - loss: 3770.9026 - root_mean_squared_error: 61.4068 - val_loss: 23559.9531 - val_root_mean_squared_error: 153.4922
# Epoch 19/1000
# 6/6 - 1s - loss: 3515.3328 - root_mean_squared_error: 59.2894 - val_loss: 19525.5625 - val_root_mean_squared_error: 139.7335
# Epoch 20/1000
# 6/6 - 1s - loss: 3158.1426 - root_mean_squared_error: 56.1964 - val_loss: 16634.3047 - val_root_mean_squared_error: 128.9736
# Epoch 21/1000
# 6/6 - 1s - loss: 2862.2253 - root_mean_squared_error: 53.4988 - val_loss: 15652.1885 - val_root_mean_squared_error: 125.1083
# Epoch 22/1000
# 6/6 - 1s - loss: 3036.7529 - root_mean_squared_error: 55.1058 - val_loss: 10492.4902 - val_root_mean_squared_error: 102.4324
# Epoch 23/1000
# 6/6 - 1s - loss: 3012.6116 - root_mean_squared_error: 54.8863 - val_loss: 8626.2715 - val_root_mean_squared_error: 92.8772
# Epoch 24/1000
# 6/6 - 1s - loss: 2664.4309 - root_mean_squared_error: 51.6171 - val_loss: 8780.6641 - val_root_mean_squared_error: 93.7046
# Epoch 25/1000
# 6/6 - 1s - loss: 2365.5874 - root_mean_squared_error: 48.6362 - val_loss: 9710.4775 - val_root_mean_squared_error: 98.5412
# Epoch 26/1000
# 6/6 - 1s - loss: 2182.8347 - root_mean_squared_error: 46.7197 - val_loss: 11060.9287 - val_root_mean_squared_error: 105.1705
# Epoch 27/1000
# 6/6 - 1s - loss: 2010.2698 - root_mean_squared_error: 44.8349 - val_loss: 11728.4609 - val_root_mean_squared_error: 108.2975
# Epoch 28/1000
# 6/6 - 1s - loss: 1889.7865 - root_mean_squared_error: 43.4705 - val_loss: 14288.8418 - val_root_mean_squared_error: 119.5355
# Epoch 29/1000
# 6/6 - 1s - loss: 1828.2935 - root_mean_squared_error: 42.7573 - val_loss: 14862.8174 - val_root_mean_squared_error: 121.9127
# Epoch 30/1000
# 6/6 - 1s - loss: 1783.4348 - root_mean_squared_error: 42.2295 - val_loss: 17459.5254 - val_root_mean_squared_error: 132.1341
# Epoch 31/1000
# 6/6 - 1s - loss: 1844.4187 - root_mean_squared_error: 42.9455 - val_loss: 18084.2891 - val_root_mean_squared_error: 134.4774
# Epoch 32/1000
# 6/6 - 1s - loss: 1806.1635 - root_mean_squared_error: 42.4977 - val_loss: 15752.8184 - val_root_mean_squared_error: 125.5098
# Epoch 33/1000
# 6/6 - 1s - loss: 1843.5363 - root_mean_squared_error: 42.9352 - val_loss: 23701.3027 - val_root_mean_squared_error: 153.9519
# Epoch 34/1000
# 6/6 - 1s - loss: 1917.6793 - root_mean_squared_error: 43.7901 - val_loss: 22191.3848 - val_root_mean_squared_error: 148.9674
# Epoch 35/1000
# 6/6 - 1s - loss: 1812.6084 - root_mean_squared_error: 42.5735 - val_loss: 23952.9785 - val_root_mean_squared_error: 154.7672
# Epoch 36/1000
# 6/6 - 1s - loss: 1620.1307 - root_mean_squared_error: 40.2495 - val_loss: 25640.1680 - val_root_mean_squared_error: 160.1251
# Epoch 37/1000
# 6/6 - 1s - loss: 1562.2206 - root_mean_squared_error: 39.5236 - val_loss: 29332.7012 - val_root_mean_squared_error: 171.2676
# Epoch 38/1000
# 6/6 - 1s - loss: 1487.4144 - root_mean_squared_error: 38.5656 - val_loss: 28550.7910 - val_root_mean_squared_error: 168.9695
# Epoch 39/1000
# 6/6 - 1s - loss: 1463.1057 - root_mean_squared_error: 38.2491 - val_loss: 24043.2109 - val_root_mean_squared_error: 155.0584
# Epoch 40/1000
# 6/6 - 1s - loss: 1449.4766 - root_mean_squared_error: 38.0706 - val_loss: 29152.1680 - val_root_mean_squared_error: 170.7397
# Epoch 41/1000
# 6/6 - 1s - loss: 1525.8899 - root_mean_squared_error: 39.0612 - val_loss: 24175.3262 - val_root_mean_squared_error: 155.4838
# Epoch 42/1000
# 6/6 - 1s - loss: 1448.4152 - root_mean_squared_error: 38.0566 - val_loss: 24675.7949 - val_root_mean_squared_error: 157.0850
# Epoch 43/1000
# 6/6 - 1s - loss: 1374.0096 - root_mean_squared_error: 37.0662 - val_loss: 23307.6758 - val_root_mean_squared_error: 152.6682
# Epoch 44/1000
# 6/6 - 1s - loss: 1290.3481 - root_mean_squared_error: 35.9199 - val_loss: 21475.1445 - val_root_mean_squared_error: 146.5436
# Epoch 45/1000
# 6/6 - 1s - loss: 1255.5996 - root_mean_squared_error: 35.4329 - val_loss: 19304.6641 - val_root_mean_squared_error: 138.9408
# Epoch 46/1000
# 6/6 - 1s - loss: 1279.8098 - root_mean_squared_error: 35.7729 - val_loss: 20039.0469 - val_root_mean_squared_error: 141.5589
# Epoch 47/1000
# 6/6 - 1s - loss: 1299.2356 - root_mean_squared_error: 36.0434 - val_loss: 20481.4570 - val_root_mean_squared_error: 143.1131
# Epoch 48/1000
# 6/6 - 1s - loss: 1269.4965 - root_mean_squared_error: 35.6284 - val_loss: 21156.5684 - val_root_mean_squared_error: 145.4526
# Epoch 49/1000
# 6/6 - 1s - loss: 1172.7679 - root_mean_squared_error: 34.2441 - val_loss: 23335.2012 - val_root_mean_squared_error: 152.7583
# Epoch 50/1000
# 6/6 - 1s - loss: 1126.7142 - root_mean_squared_error: 33.5649 - val_loss: 29731.5156 - val_root_mean_squared_error: 172.4280
# Epoch 51/1000
# 6/6 - 1s - loss: 1096.9028 - root_mean_squared_error: 33.1178 - val_loss: 34836.9453 - val_root_mean_squared_error: 186.6463
# Epoch 52/1000
# 6/6 - 1s - loss: 1073.1012 - root_mean_squared_error: 32.7565 - val_loss: 38147.8555 - val_root_mean_squared_error: 195.3145
# Epoch 53/1000
# 6/6 - 1s - loss: 1036.3452 - root_mean_squared_error: 32.1906 - val_loss: 36627.4219 - val_root_mean_squared_error: 191.3826
# Epoch 54/1000
# 6/6 - 1s - loss: 1035.0759 - root_mean_squared_error: 32.1708 - val_loss: 37092.2812 - val_root_mean_squared_error: 192.5933
# Epoch 55/1000
# 6/6 - 1s - loss: 969.7437 - root_mean_squared_error: 31.1389 - val_loss: 40513.3750 - val_root_mean_squared_error: 201.2791
# Epoch 56/1000
# 6/6 - 1s - loss: 982.5759 - root_mean_squared_error: 31.3443 - val_loss: 38080.9492 - val_root_mean_squared_error: 195.1431
# Epoch 57/1000
# 6/6 - 1s - loss: 973.2574 - root_mean_squared_error: 31.1953 - val_loss: 48620.3164 - val_root_mean_squared_error: 220.4999
# Epoch 58/1000
# 6/6 - 1s - loss: 920.1206 - root_mean_squared_error: 30.3316 - val_loss: 47104.2188 - val_root_mean_squared_error: 217.0348
# Epoch 59/1000
# 6/6 - 1s - loss: 872.7756 - root_mean_squared_error: 29.5409 - val_loss: 42849.4844 - val_root_mean_squared_error: 207.0009
# Epoch 60/1000
# 6/6 - 1s - loss: 880.4739 - root_mean_squared_error: 29.6709 - val_loss: 52640.1328 - val_root_mean_squared_error: 229.4341
# Epoch 61/1000
# 6/6 - 1s - loss: 814.9590 - root_mean_squared_error: 28.5455 - val_loss: 50958.0625 - val_root_mean_squared_error: 225.7387
# Epoch 62/1000
# 6/6 - 1s - loss: 756.9960 - root_mean_squared_error: 27.5115 - val_loss: 46883.1953 - val_root_mean_squared_error: 216.5250
# Epoch 63/1000
#
# Epoch 00063: ReduceLROnPlateau reducing learning rate to 0.0007000000332482159.
# 6/6 - 1s - loss: 691.1490 - root_mean_squared_error: 26.2875 - val_loss: 54141.7227 - val_root_mean_squared_error: 232.6835
# Epoch 64/1000
# 6/6 - 1s - loss: 610.9131 - root_mean_squared_error: 24.7143 - val_loss: 47406.5938 - val_root_mean_squared_error: 217.7303
# Epoch 65/1000
# 6/6 - 1s - loss: 560.8536 - root_mean_squared_error: 23.6799 - val_loss: 44866.3711 - val_root_mean_squared_error: 211.8166
# Epoch 66/1000
# 6/6 - 1s - loss: 552.3022 - root_mean_squared_error: 23.4987 - val_loss: 38641.5625 - val_root_mean_squared_error: 196.5743
# Epoch 67/1000
# 6/6 - 1s - loss: 581.7861 - root_mean_squared_error: 24.1179 - val_loss: 32136.9102 - val_root_mean_squared_error: 179.2674
# Epoch 68/1000
# 6/6 - 1s - loss: 582.1544 - root_mean_squared_error: 24.1255 - val_loss: 25460.2754 - val_root_mean_squared_error: 159.5624
# Epoch 69/1000
# 6/6 - 1s - loss: 598.9561 - root_mean_squared_error: 24.4712 - val_loss: 23846.2871 - val_root_mean_squared_error: 154.4221
# Epoch 70/1000
# 6/6 - 1s - loss: 540.7302 - root_mean_squared_error: 23.2511 - val_loss: 22469.1816 - val_root_mean_squared_error: 149.8969
# Epoch 71/1000
# 6/6 - 1s - loss: 500.3042 - root_mean_squared_error: 22.3649 - val_loss: 21396.6055 - val_root_mean_squared_error: 146.2754
# Epoch 72/1000
# 6/6 - 1s - loss: 455.2600 - root_mean_squared_error: 21.3341 - val_loss: 23400.0703 - val_root_mean_squared_error: 152.9704
# Epoch 73/1000
# 6/6 - 1s - loss: 423.9529 - root_mean_squared_error: 20.5873 - val_loss: 25608.7266 - val_root_mean_squared_error: 160.0269
# Epoch 74/1000
# 6/6 - 1s - loss: 419.3850 - root_mean_squared_error: 20.4761 - val_loss: 21630.7734 - val_root_mean_squared_error: 147.0737
# Epoch 75/1000
# 6/6 - 1s - loss: 429.0990 - root_mean_squared_error: 20.7119 - val_loss: 18964.8496 - val_root_mean_squared_error: 137.7125
# Epoch 76/1000
# 6/6 - 1s - loss: 466.2743 - root_mean_squared_error: 21.5907 - val_loss: 13680.2256 - val_root_mean_squared_error: 116.9620
# Epoch 77/1000
# 6/6 - 1s - loss: 432.5119 - root_mean_squared_error: 20.7941 - val_loss: 12692.7881 - val_root_mean_squared_error: 112.6618
# Epoch 78/1000
# 6/6 - 1s - loss: 438.8718 - root_mean_squared_error: 20.9465 - val_loss: 18321.7031 - val_root_mean_squared_error: 135.3573
# Epoch 79/1000
# 6/6 - 1s - loss: 357.5036 - root_mean_squared_error: 18.9047 - val_loss: 15623.0645 - val_root_mean_squared_error: 124.9918
# Epoch 80/1000
# 6/6 - 1s - loss: 326.6156 - root_mean_squared_error: 18.0693 - val_loss: 11825.1504 - val_root_mean_squared_error: 108.7430
# Epoch 81/1000
# 6/6 - 1s - loss: 290.1016 - root_mean_squared_error: 17.0290 - val_loss: 12830.5898 - val_root_mean_squared_error: 113.2717
# Epoch 82/1000
# 6/6 - 1s - loss: 262.6234 - root_mean_squared_error: 16.2021 - val_loss: 11334.7637 - val_root_mean_squared_error: 106.4643
# Epoch 83/1000
# 6/6 - 1s - loss: 236.5773 - root_mean_squared_error: 15.3773 - val_loss: 10559.0850 - val_root_mean_squared_error: 102.7568
# Epoch 84/1000
# 6/6 - 1s - loss: 225.1539 - root_mean_squared_error: 15.0012 - val_loss: 9955.8799 - val_root_mean_squared_error: 99.7786
# Epoch 85/1000
# 6/6 - 1s - loss: 212.3387 - root_mean_squared_error: 14.5678 - val_loss: 10205.6523 - val_root_mean_squared_error: 101.0224
# Epoch 86/1000
# 6/6 - 1s - loss: 206.5894 - root_mean_squared_error: 14.3692 - val_loss: 10626.7607 - val_root_mean_squared_error: 103.0856
# Epoch 87/1000
# 6/6 - 1s - loss: 211.0976 - root_mean_squared_error: 14.5252 - val_loss: 11430.4043 - val_root_mean_squared_error: 106.9125
# Epoch 88/1000
# 6/6 - 1s - loss: 235.1711 - root_mean_squared_error: 15.3315 - val_loss: 11609.5801 - val_root_mean_squared_error: 107.7472
# Epoch 89/1000
# 6/6 - 1s - loss: 270.4762 - root_mean_squared_error: 16.4426 - val_loss: 9840.6338 - val_root_mean_squared_error: 99.1994
# Epoch 90/1000
# 6/6 - 1s - loss: 297.5509 - root_mean_squared_error: 17.2463 - val_loss: 7185.8218 - val_root_mean_squared_error: 84.7685
# Epoch 91/1000
# 6/6 - 1s - loss: 335.6316 - root_mean_squared_error: 18.3171 - val_loss: 8251.6074 - val_root_mean_squared_error: 90.8377
# Epoch 92/1000
# 6/6 - 1s - loss: 301.5029 - root_mean_squared_error: 17.3605 - val_loss: 6869.2236 - val_root_mean_squared_error: 82.8801
# Epoch 93/1000
# 6/6 - 1s - loss: 299.3249 - root_mean_squared_error: 17.2976 - val_loss: 7427.9795 - val_root_mean_squared_error: 86.1851
# Epoch 94/1000
# 6/6 - 1s - loss: 266.0098 - root_mean_squared_error: 16.3062 - val_loss: 7896.0073 - val_root_mean_squared_error: 88.8588
# Epoch 95/1000
# 6/6 - 1s - loss: 240.5288 - root_mean_squared_error: 15.5052 - val_loss: 6596.9229 - val_root_mean_squared_error: 81.2207
# Epoch 96/1000
# 6/6 - 1s - loss: 216.5940 - root_mean_squared_error: 14.7131 - val_loss: 7355.8262 - val_root_mean_squared_error: 85.7654
# Epoch 97/1000
# 6/6 - 1s - loss: 200.5039 - root_mean_squared_error: 14.1558 - val_loss: 7144.6973 - val_root_mean_squared_error: 84.5256
# Epoch 98/1000
# 6/6 - 1s - loss: 190.9459 - root_mean_squared_error: 13.8141 - val_loss: 6223.3521 - val_root_mean_squared_error: 78.8875
# Epoch 99/1000
# 6/6 - 1s - loss: 185.6346 - root_mean_squared_error: 13.6205 - val_loss: 6480.0742 - val_root_mean_squared_error: 80.4982
# Epoch 100/1000
# 6/6 - 1s - loss: 188.5093 - root_mean_squared_error: 13.7256 - val_loss: 6511.0396 - val_root_mean_squared_error: 80.6903
# Epoch 101/1000
# 6/6 - 1s - loss: 187.4174 - root_mean_squared_error: 13.6858 - val_loss: 5709.5732 - val_root_mean_squared_error: 75.5609
# Epoch 102/1000
# 6/6 - 1s - loss: 185.6264 - root_mean_squared_error: 13.6202 - val_loss: 5584.3804 - val_root_mean_squared_error: 74.7279
# Epoch 103/1000
# 6/6 - 1s - loss: 195.9383 - root_mean_squared_error: 13.9936 - val_loss: 5955.7676 - val_root_mean_squared_error: 77.1729
# Epoch 104/1000
# 6/6 - 1s - loss: 197.1773 - root_mean_squared_error: 14.0378 - val_loss: 6314.2793 - val_root_mean_squared_error: 79.4617
# Epoch 105/1000
# 6/6 - 1s - loss: 195.9267 - root_mean_squared_error: 13.9932 - val_loss: 6437.3667 - val_root_mean_squared_error: 80.2325
# Epoch 106/1000
# 6/6 - 1s - loss: 197.7448 - root_mean_squared_error: 14.0580 - val_loss: 6130.9365 - val_root_mean_squared_error: 78.2995
# Epoch 107/1000
# 6/6 - 1s - loss: 206.4588 - root_mean_squared_error: 14.3646 - val_loss: 5777.9229 - val_root_mean_squared_error: 76.0119
# Epoch 108/1000
# 6/6 - 1s - loss: 207.9193 - root_mean_squared_error: 14.4153 - val_loss: 5757.6177 - val_root_mean_squared_error: 75.8782
# Epoch 109/1000
# 6/6 - 1s - loss: 214.1769 - root_mean_squared_error: 14.6308 - val_loss: 5308.1094 - val_root_mean_squared_error: 72.8560
# Epoch 110/1000
# 6/6 - 1s - loss: 237.6542 - root_mean_squared_error: 15.4122 - val_loss: 5089.1680 - val_root_mean_squared_error: 71.3376
# Epoch 111/1000
# 6/6 - 1s - loss: 274.7440 - root_mean_squared_error: 16.5718 - val_loss: 5101.3516 - val_root_mean_squared_error: 71.4229
# Epoch 112/1000
# 6/6 - 1s - loss: 303.6257 - root_mean_squared_error: 17.4215 - val_loss: 5562.0566 - val_root_mean_squared_error: 74.5784
# Epoch 113/1000
# 6/6 - 1s - loss: 314.4713 - root_mean_squared_error: 17.7300 - val_loss: 6074.3008 - val_root_mean_squared_error: 77.9370
# Epoch 114/1000
# 6/6 - 1s - loss: 375.4999 - root_mean_squared_error: 19.3748 - val_loss: 5053.1597 - val_root_mean_squared_error: 71.0847
# Epoch 115/1000
# 6/6 - 1s - loss: 320.6951 - root_mean_squared_error: 17.9047 - val_loss: 4980.2573 - val_root_mean_squared_error: 70.5701
# Epoch 116/1000
# 6/6 - 1s - loss: 280.7499 - root_mean_squared_error: 16.7521 - val_loss: 4983.3955 - val_root_mean_squared_error: 70.5923
# Epoch 117/1000
# 6/6 - 1s - loss: 242.0091 - root_mean_squared_error: 15.5528 - val_loss: 4957.3374 - val_root_mean_squared_error: 70.4075
# Epoch 118/1000
# 6/6 - 1s - loss: 209.7307 - root_mean_squared_error: 14.4780 - val_loss: 5613.8345 - val_root_mean_squared_error: 74.9247
# Epoch 119/1000
# 6/6 - 1s - loss: 182.7449 - root_mean_squared_error: 13.5139 - val_loss: 5300.1636 - val_root_mean_squared_error: 72.8014
# Epoch 120/1000
# 6/6 - 1s - loss: 162.0651 - root_mean_squared_error: 12.7258 - val_loss: 4855.9731 - val_root_mean_squared_error: 69.6840
# Epoch 121/1000
# 6/6 - 1s - loss: 147.8946 - root_mean_squared_error: 12.1563 - val_loss: 4960.6323 - val_root_mean_squared_error: 70.4309
# Epoch 122/1000
# 6/6 - 1s - loss: 137.7292 - root_mean_squared_error: 11.7307 - val_loss: 4995.1997 - val_root_mean_squared_error: 70.6759
# Epoch 123/1000
# 6/6 - 1s - loss: 137.7538 - root_mean_squared_error: 11.7318 - val_loss: 5106.9644 - val_root_mean_squared_error: 71.4622
# Epoch 124/1000
# 6/6 - 1s - loss: 150.4202 - root_mean_squared_error: 12.2597 - val_loss: 4934.4038 - val_root_mean_squared_error: 70.2445
# Epoch 125/1000
# 6/6 - 1s - loss: 151.3980 - root_mean_squared_error: 12.2995 - val_loss: 4821.0679 - val_root_mean_squared_error: 69.4331
# Epoch 126/1000
# 6/6 - 1s - loss: 157.5603 - root_mean_squared_error: 12.5476 - val_loss: 5253.0859 - val_root_mean_squared_error: 72.4773
# Epoch 127/1000
# 6/6 - 1s - loss: 183.9276 - root_mean_squared_error: 13.5576 - val_loss: 5079.9336 - val_root_mean_squared_error: 71.2728
# Epoch 128/1000
# 6/6 - 1s - loss: 178.4217 - root_mean_squared_error: 13.3530 - val_loss: 5175.2378 - val_root_mean_squared_error: 71.9383
# Epoch 129/1000
# 6/6 - 1s - loss: 176.7299 - root_mean_squared_error: 13.2895 - val_loss: 5454.6206 - val_root_mean_squared_error: 73.8546
# Epoch 130/1000
# 6/6 - 1s - loss: 170.6672 - root_mean_squared_error: 13.0594 - val_loss: 4842.5093 - val_root_mean_squared_error: 69.5873
# Epoch 131/1000
# 6/6 - 1s - loss: 160.3997 - root_mean_squared_error: 12.6602 - val_loss: 4762.8320 - val_root_mean_squared_error: 69.0124
# Epoch 132/1000
# 6/6 - 1s - loss: 158.0986 - root_mean_squared_error: 12.5690 - val_loss: 4925.2368 - val_root_mean_squared_error: 70.1792
# Epoch 133/1000
# 6/6 - 1s - loss: 150.7435 - root_mean_squared_error: 12.2729 - val_loss: 5013.7788 - val_root_mean_squared_error: 70.8072
# Epoch 134/1000
# 6/6 - 1s - loss: 152.2347 - root_mean_squared_error: 12.3335 - val_loss: 4894.5146 - val_root_mean_squared_error: 69.9600
# Epoch 135/1000
# 6/6 - 1s - loss: 163.7239 - root_mean_squared_error: 12.7908 - val_loss: 4893.5181 - val_root_mean_squared_error: 69.9528
# Epoch 136/1000
# 6/6 - 1s - loss: 185.6487 - root_mean_squared_error: 13.6209 - val_loss: 4799.2197 - val_root_mean_squared_error: 69.2755
# Epoch 137/1000
# 6/6 - 1s - loss: 186.3470 - root_mean_squared_error: 13.6465 - val_loss: 5315.6265 - val_root_mean_squared_error: 72.9075
# Epoch 138/1000
# 6/6 - 1s - loss: 201.5419 - root_mean_squared_error: 14.1923 - val_loss: 5173.4277 - val_root_mean_squared_error: 71.9257
# Epoch 139/1000
# 6/6 - 1s - loss: 206.5532 - root_mean_squared_error: 14.3678 - val_loss: 4750.3213 - val_root_mean_squared_error: 68.9217
